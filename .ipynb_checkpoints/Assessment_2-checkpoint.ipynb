# %% [markdown]
# # Abiodun SQL Assessment

# %% [markdown]
# ## Loading necessary libraries

# %%
# Loading sqlite3, pandas and loading the accident data
import sqlite3 
import pandas as pd
con = sqlite3.connect("accident_data_v1.0.0_2023.db") 
cur = con.cursor()
cur

# %% [markdown]
# ## Extraction of Information about Each Table

# %%
# Executing a PRAGMA query to retrieve information about the columns in the "accident" table
col_info = cur.execute(f"PRAGMA table_info(accident)")

# Fetching all the results of the query and storing them in the variable 'accident'
accident = col_info.fetchall()

# %%
accident
# Out:
# [(0, 'accident_index', '', 0, None, 1),
#  (1, 'accident_year', '', 0, None, 0),
#  (2, 'accident_reference', '', 0, None, 0),
#  (3, 'location_easting_osgr', '', 0, None, 0),
#  (4, 'location_northing_osgr', '', 0, None, 0),
#  (5, 'longitude', '', 0, None, 0),
#  (6, 'latitude', '', 0, None, 0),
#  (7, 'police_force', '', 0, None, 0),
#  (8, 'accident_severity', '', 0, None, 0),
#  (9, 'number_of_vehicles', '', 0, None, 0),
#  (10, 'number_of_casualties', '', 0, None, 0),
#  (11, 'date', '', 0, None, 0),
#  (12, 'day_of_week', '', 0, None, 0),
#  (13, 'time', '', 0, None, 0),
#  (14, 'local_authority_district', '', 0, None, 0),
#  (15, 'local_authority_ons_district', '', 0, None, 0),
#  (16, 'local_authority_highway', '', 0, None, 0),
#  (17, 'first_road_class', '', 0, None, 0),
#  (18, 'first_road_number', '', 0, None, 0),
#  (19, 'road_type', '', 0, None, 0),
#  (20, 'speed_limit', '', 0, None, 0),
#  (21, 'junction_detail', '', 0, None, 0),
# ...

# %%
# Executing a PRAGMA query to retrieve information about the columns in the 'vehicle' table
col_info = cur.execute(f"PRAGMA table_info(casualty)") 
# Fetching all the column information for the 'vehicle' table
vehicle = col_info.fetchall()

# %%
vehicle
# Out:
# [(0, 'casualty_index', '', 0, None, 1),
#  (1, 'accident_index', '', 0, None, 0),
#  (2, 'accident_year', '', 0, None, 0),
#  (3, 'accident_reference', '', 0, None, 0),
#  (4, 'vehicle_reference', '', 0, None, 0),
#  (5, 'casualty_reference', '', 0, None, 0),
#  (6, 'casualty_class', '', 0, None, 0),
#  (7, 'sex_of_casualty', '', 0, None, 0),
#  (8, 'age_of_casualty', '', 0, None, 0),
#  (9, 'age_band_of_casualty', '', 0, None, 0),
#  (10, 'casualty_severity', '', 0, None, 0),
#  (11, 'pedestrian_location', '', 0, None, 0),
#  (12, 'pedestrian_movement', '', 0, None, 0),
#  (13, 'car_passenger', '', 0, None, 0),
#  (14, 'bus_or_coach_passenger', '', 0, None, 0),
#  (15, 'pedestrian_road_maintenance_worker', '', 0, None, 0),
#  (16, 'casualty_type', '', 0, None, 0),
#  (17, 'casualty_home_area_type', '', 0, None, 0),
#  (18, 'casualty_imd_decile', '', 0, None, 0)]

# %%
# Executing a PRAGMA query to retrieve information about the columns in the 'casualty' table
col_info = cur.execute(f"PRAGMA table_info(casualty)") 
# Fetching all the column information for the 'casualty' table
casualty = col_info.fetchall()

# %%
casualty
# Out:
# [(0, 'casualty_index', '', 0, None, 1),
#  (1, 'accident_index', '', 0, None, 0),
#  (2, 'accident_year', '', 0, None, 0),
#  (3, 'accident_reference', '', 0, None, 0),
#  (4, 'vehicle_reference', '', 0, None, 0),
#  (5, 'casualty_reference', '', 0, None, 0),
#  (6, 'casualty_class', '', 0, None, 0),
#  (7, 'sex_of_casualty', '', 0, None, 0),
#  (8, 'age_of_casualty', '', 0, None, 0),
#  (9, 'age_band_of_casualty', '', 0, None, 0),
#  (10, 'casualty_severity', '', 0, None, 0),
#  (11, 'pedestrian_location', '', 0, None, 0),
#  (12, 'pedestrian_movement', '', 0, None, 0),
#  (13, 'car_passenger', '', 0, None, 0),
#  (14, 'bus_or_coach_passenger', '', 0, None, 0),
#  (15, 'pedestrian_road_maintenance_worker', '', 0, None, 0),
#  (16, 'casualty_type', '', 0, None, 0),
#  (17, 'casualty_home_area_type', '', 0, None, 0),
#  (18, 'casualty_imd_decile', '', 0, None, 0)]

# %%
# Executing a PRAGMA query to get information about the columns in the 'lsoa' table
col_info = cur.execute(f"PRAGMA table_info(lsoa)")

# Fetching all the column information from the executed query
lsoa = col_info.fetchall()

# %%
lsoa
# Out:
# [(0, 'objectid', '', 0, None, 1),
#  (1, 'lsoa01cd', '', 0, None, 0),
#  (2, 'lsoa01nm', '', 0, None, 0),
#  (3, 'lsoa01nmw', '', 0, None, 0),
#  (4, 'shape__area', '', 0, None, 0),
#  (5, 'shape__length', '', 0, None, 0),
#  (6, 'globalid', '', 0, None, 0)]

# %%
# Reading data from the 'accident' table in the database using a SQL query
accident_df = pd.read_sql_query('SELECT * FROM accident', con)

# %%
accident_df
# Out:
#        accident_index  accident_year accident_reference  \
# 0       2017010001708           2017          010001708
# 1       2017010009342           2017          010009342
# 2       2017010009344           2017          010009344
# 3       2017010009348           2017          010009348
# 4       2017010009350           2017          010009350
# ...               ...            ...                ...
# 461347  2020991027064           2020          991027064
# 461348  2020991029573           2020          991029573
# 461349  2020991030297           2020          991030297
# 461350  2020991030900           2020          991030900
# 461351  2020991032575           2020          991032575
#
#         location_easting_osgr  location_northing_osgr  longitude   latitude  \
# 0                    532920.0                196330.0  -0.080107  51.650061
# 1                    526790.0                181970.0  -0.173845  51.522425
# ...

# %%
# Reading data from the 'vehicle' table in the database using a SQL query
vehicle_df = pd.read_sql_query('SELECT * FROM vehicle', con)

# %%
vehicle_df
# Out:
#         vehicle_index accident_index  accident_year accident_reference  \
# 0                   0  2017010001708           2017          010001708
# 1                   1  2017010001708           2017          010001708
# 2                   2  2017010009342           2017          010009342
# 3                   3  2017010009342           2017          010009342
# 4                   4  2017010009344           2017          010009344
# ...               ...            ...            ...                ...
# 849086         849086  2020991030297           2020          991030297
# 849087         849087  2020991030297           2020          991030297
# 849088         849088  2020991030900           2020          991030900
# 849089         849089  2020991030900           2020          991030900
# 849090         849090  2020991032575           2020          991032575
#
#         vehicle_reference  vehicle_type  towing_and_articulation  \
# ...

# %%
# Reading data from the 'casualty' table in the database using a SQL query
casualty_df = pd.read_sql_query('SELECT * FROM casualty', con)

# %%
casualty_df
# Out:
#         casualty_index accident_index  accident_year accident_reference  \
# 0                    0  2017010001708           2017          010001708
# 1                    1  2017010001708           2017          010001708
# 2                    2  2017010001708           2017          010001708
# 3                    3  2017010009342           2017          010009342
# 4                    4  2017010009344           2017          010009344
# ...                ...            ...            ...                ...
# 600327          600327  2020991027064           2020          991027064
# 600328          600328  2020991029573           2020          991029573
# 600329          600329  2020991030297           2020          991030297
# 600330          600330  2020991030900           2020          991030900
# 600331          600331  2020991032575           2020          991032575
#
#         vehicle_reference  casualty_reference  casualty_class  \
# ...

# %%
# Reading data from the 'lsoa' table in the database using a SQL query
lsoa_df = pd.read_sql_query('SELECT * FROM lsoa', con)

# %%
lsoa_df
# Out:
#        objectid   lsoa01cd             lsoa01nm            lsoa01nmw  \
# 0             1  E01000001  City of London 001A  City of London 001A
# 1             2  E01000002  City of London 001B  City of London 001B
# 2             3  E01000003  City of London 001C  City of London 001C
# 3             4  E01000004  City of London 001D  City of London 001D
# 4             5  E01000005  City of London 001E  City of London 001E
# ...         ...        ...                  ...                  ...
# 34373     34374  W01001892         Cardiff 020D        Caerdydd 020D
# 34374     34375  W01001893         Cardiff 010B        Caerdydd 010B
# 34375     34376  W01001894         Cardiff 010C        Caerdydd 010C
# 34376     34377  W01001895         Cardiff 010D        Caerdydd 010D
# 34377     34378  W01001896         Cardiff 020E        Caerdydd 020E
#
#         shape__area  shape__length                              globalid
# ...

# %% [markdown]
# ## Extracting the 2020 Data for Accident, Vehicle and Casualty

# %%
# Extracting the year 2020 accident Cases
accident_2020 = pd.read_sql_query("SELECT * FROM accident WHERE accident_year = 2020", con)
accident_2020
# Out:
#       accident_index  accident_year accident_reference  location_easting_osgr  \
# 0      2020010219808           2020          010219808               521389.0
# 1      2020010220496           2020          010220496               529337.0
# 2      2020010228005           2020          010228005               526432.0
# 3      2020010228006           2020          010228006               538676.0
# 4      2020010228011           2020          010228011               529324.0
# ...              ...            ...                ...                    ...
# 91194  2020991027064           2020          991027064               343034.0
# 91195  2020991029573           2020          991029573               257963.0
# 91196  2020991030297           2020          991030297               383664.0
# 91197  2020991030900           2020          991030900               277161.0
# 91198  2020991032575           2020          991032575               240402.0
#
# ...

# %%
# Extracting the year 2020 vehicle Cases
vehicle_2020 = pd.read_sql_query("SELECT * FROM vehicle WHERE accident_year = 2020", con)
vehicle_2020
# Out:
#         vehicle_index accident_index  accident_year accident_reference  \
# 0              681716  2020010219808           2020          010219808
# 1              681717  2020010220496           2020          010220496
# 2              681718  2020010228005           2020          010228005
# 3              681719  2020010228006           2020          010228006
# 4              681720  2020010228011           2020          010228011
# ...               ...            ...            ...                ...
# 167370         849086  2020991030297           2020          991030297
# 167371         849087  2020991030297           2020          991030297
# 167372         849088  2020991030900           2020          991030900
# 167373         849089  2020991030900           2020          991030900
# 167374         849090  2020991032575           2020          991032575
#
#         vehicle_reference  vehicle_type  towing_and_articulation  \
# ...

# %%
# Extracting the year 2020 casualty Cases
casualty_2020 = pd.read_sql_query("SELECT * FROM casualty WHERE accident_year = 2020", con)
casualty_2020
# Out:
#         casualty_index accident_index  accident_year accident_reference  \
# 0               484748  2020010219808           2020          010219808
# 1               484749  2020010220496           2020          010220496
# 2               484750  2020010220496           2020          010220496
# 3               484751  2020010228005           2020          010228005
# 4               484752  2020010228006           2020          010228006
# ...                ...            ...            ...                ...
# 115579          600327  2020991027064           2020          991027064
# 115580          600328  2020991029573           2020          991029573
# 115581          600329  2020991030297           2020          991030297
# 115582          600330  2020991030900           2020          991030900
# 115583          600331  2020991032575           2020          991032575
#
#         vehicle_reference  casualty_reference  casualty_class  \
# ...

# %% [markdown]
# ## Data EDA and Cleaning

# %%
accident_2020.info() # Checking for missing value in Accident Table
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 91199 entries, 0 to 91198
# Data columns (total 36 columns):
#  #   Column                                       Non-Null Count  Dtype
# ---  ------                                       --------------  -----
#  0   accident_index                               91199 non-null  object
#  1   accident_year                                91199 non-null  int64
#  2   accident_reference                           91199 non-null  object
#  3   location_easting_osgr                        91185 non-null  float64
#  4   location_northing_osgr                       91185 non-null  float64
#  5   longitude                                    91185 non-null  float64
#  6   latitude                                     91185 non-null  float64
#  7   police_force                                 91199 non-null  int64
#  8   accident_severity                            91199 non-null  int64
# ...

# %% [markdown]
# #### There are missing values in the accident table
# #### 3  location_easting_osgr 91185 non-null  float64
# #### 4  location_northing_osgr 91185 non-null  float64
# #### 5  longitude 91185 non-null  float64
# #### 6  latitude 91185 non-null  float64

# %%
vehicle_2020.info() # Checking for missing value in Vehicle Table
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 167375 entries, 0 to 167374
# Data columns (total 28 columns):
#  #   Column                            Non-Null Count   Dtype
# ---  ------                            --------------   -----
#  0   vehicle_index                     167375 non-null  int64
#  1   accident_index                    167375 non-null  object
#  2   accident_year                     167375 non-null  int64
#  3   accident_reference                167375 non-null  object
#  4   vehicle_reference                 167375 non-null  int64
#  5   vehicle_type                      167375 non-null  int64
#  6   towing_and_articulation           167375 non-null  int64
#  7   vehicle_manoeuvre                 167375 non-null  int64
#  8   vehicle_direction_from            167375 non-null  int64
#  9   vehicle_direction_to              167375 non-null  int64
#  10  vehicle_location_restricted_lane  167375 non-null  int64
# ...

# %% [markdown]
# ### No missing values in Vehicle Table

# %%
casualty_2020.info() # Checking for missing value in Casualty Table
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 115584 entries, 0 to 115583
# Data columns (total 19 columns):
#  #   Column                              Non-Null Count   Dtype
# ---  ------                              --------------   -----
#  0   casualty_index                      115584 non-null  int64
#  1   accident_index                      115584 non-null  object
#  2   accident_year                       115584 non-null  int64
#  3   accident_reference                  115584 non-null  object
#  4   vehicle_reference                   115584 non-null  int64
#  5   casualty_reference                  115584 non-null  int64
#  6   casualty_class                      115584 non-null  int64
#  7   sex_of_casualty                     115584 non-null  int64
#  8   age_of_casualty                     115584 non-null  int64
#  9   age_band_of_casualty                115584 non-null  int64
#  10  casualty_severity                   115584 non-null  int64
# ...

# %% [markdown]
# ### No missing values in Casualty table

# %% [markdown]
# ### lsoa has no year information (from the DataFrame above) so it was left out.

# %%
# Assuming your dataset has columns: 'Date', 'Fatal', and 'Nonfatal'
# You may need to adjust column names accordingly

# Convert 'Date' column to datetime
df['Date'] = pd.to_datetime(df['Date'])

# Extracting day of the week (0 = Monday, 6 = Sunday)
df['DayOfWeek'] = df['Date'].dt.dayofweek

# Extracting hour of the day
df['HourOfDay'] = df['Date'].dt.hour

# Filtering fatal and nonfatal accidents
fatal_accidents = df[df['Fatal'] == 1]
nonfatal_accidents = df[df['Fatal'] == 0]

# Plotting fatal accidents by day of the week
fatal_by_day = fatal_accidents.groupby('DayOfWeek')['Fatal'].sum()
fatal_by_day.plot(kind='bar', title='Fatal Accidents by Day of the Week')
plt.xlabel('Day of the Week')
plt.ylabel('Number of Fatal Accidents')
plt.xticks(range(7), ['Mon', 'Tue', 'Wed', 'Thu', 'Fri', 'Sat', 'Sun'])
plt.show()

# Plotting nonfatal accidents by hour of the day
nonfatal_by_hour = nonfatal_accidents.groupby('HourOfDay')['Nonfatal'].sum()
nonfatal_by_hour.plot(kind='bar', title='Nonfatal Accidents by Hour of the Day')
plt.xlabel('Hour of the Day')
plt.ylabel('Number of Nonfatal Accidents')
plt.xticks(range(24))
plt.show()
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# Cell In[25], line 5
#       1 # Assuming your dataset has columns: 'Date', 'Fatal', and 'Nonfatal'
#       2 # You may need to adjust column names accordingly
#       3
#       4 # Convert 'Date' column to datetime
# ----> 5 df['Date'] = pd.to_datetime(df['Date'])
#       7 # Extracting day of the week (0 = Monday, 6 = Sunday)
#       8 df['DayOfWeek'] = df['Date'].dt.dayofweek
#
# NameError: name 'df' is not defined

# %% [markdown]
# ## Extracting the oldest driver age

# %%
oldest_age = cur.execute("SELECT MAX(age_of_casualty) AS oldest_driver_age FROM casualty")
max_age = oldest_age.fetchall()
max_age
# Out:
# [(102,)]

# %% [markdown]
# ## Extracting total number of vehicles with number 19

# %%
vehicle_type = cur.execute("SELECT COUNT(*) FROM vehicle WHERE vehicle_type = 19")
num_vehicles = vehicle_type.fetchall()
num_vehicles
# Out:
# [(47458,)]

# %%
if isinstance(accident_2020, pd.DataFrame):
    print('accident_2020 is a DataFrame')
else:
    print('Not a DataFrame')
# Out:
# accident_2020 is a DataFrame

# %%
all_query = """
            SELECT l.lsoa01cd, l.lsoa01nm, a.accident_index, a.sex_of_driver, c.sex_of_casualty, v.speed_limit, v.age_of_vehicle
            FROM accident a
            INNER JOIN lsoa l ON a.lsoa_of_accident = l.lsoa01cd
            INNER JOIN casualty c ON a.accident_index = c.accident_index
            INNER JOIN vehicle v ON a.accident_index = v.accident_index
            WHERE l.lsoa01nm LIKE '%Kingston Upon Hull%'
            """

# Execute the SQL query
cur.execute(sql_query)

# Fetch all the results
results = cur.fetchall()

# Convert the results into a pandas DataFrame
columns = ['LSOA Code', 'LSOA Name', 'Accident Index', 'Sex of Driver', 'Sex of Casualty', 'Speed Limit', 'Age of Vehicle']
df = pd.DataFrame(results, columns=columns)

# Display the DataFrame
print(df)
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# Cell In[29], line 11
#       1 all_query = """
#       2             SELECT l.lsoa01cd, l.lsoa01nm, a.accident_index, a.sex_of_driver, c.sex_of_casualty, v.speed_limit, v.age_of_vehicle
#       3             FROM accident a
#    (...)
#       7             WHERE l.lsoa01nm LIKE '%Kingston Upon Hull%'
#       8             """
#      10 # Execute the SQL query
# ---> 11 cur.execute(sql_query)
#      13 # Fetch all the results
#      14 results = cur.fetchall()
#
# NameError: name 'sql_query' is not defined

# %%
# Define your SQL query
all_query = """
            SELECT l.lsoa01cd, l.lsoa01nm, a.accident_index, a.sex_of_driver, c.sex_of_casualty, v.speed_limit, v.age_of_vehicle
            FROM accident a
            INNER JOIN lsoa l ON a.lsoa_of_accident = l.lsoa01cd
            INNER JOIN casualty c ON a.accident_index = c.accident_index
            INNER JOIN vehicle v ON a.accident_index = v.accident_index
            WHERE l.lsoa01nm LIKE '%Kingston Upon Hull%'
            """

# Execute the SQL query
cur.execute(all_query)

# Fetch all the results
results = cur.fetchall()

# Convert the results into a pandas DataFrame
columns = ['LSOA Code', 'LSOA Name', 'Accident Index', 'Sex of Driver', 'Sex of Casualty', 'Speed Limit', 'Age of Vehicle']
df = pd.DataFrame(results, columns=columns)

# Display the DataFrame
print(df)

# %%
to = cur.execute(SELECT l.lsoa01cd, l.lsoa01nm, a.accident_index, a.sex_of_driver, c.sex_of_casualty, v.speed_limit, v.age_of_vehicle
            FROM accident AS a
            INNER JOIN lsoa AS l ON a.lsoa_of_accident = l.lsoa01cd
            INNER JOIN casualty AS c ON a.accident_index = c.accident_index
            INNER JOIN vehicle AS v ON a.accident_index = v.accident_index
            WHERE l.lsoa01nm LIKE %Kingston Upon Hull%;
# Out:
#   Cell In[30], line 1
#     to = cur.execute(SELECT l.lsoa01cd, l.lsoa01nm, a.accident_index, a.sex_of_driver, c.sex_of_casualty, v.speed_limit, v.age_of_vehicle
#                      ^
# SyntaxError: invalid syntax. Perhaps you forgot a comma?

# %%
# Fetching all the results
results = cur.fetchall()

# Converting the results into a pandas DataFrame
columns = ['LSOA Code', 'LSOA Name', 'Accident Index', 'Sex of Driver', 'Sex of Casualty', 'Speed Limit', 'Age of Vehicle']
df = pd.DataFrame(results, columns=columns)

# %%
accident_df = pd.read_sql_query('SELECT * FROM accident where accident_year == 2020' , con) # Extracting 2020 data

# %%
display(accident_df)
# Out:
#       accident_index  accident_year accident_reference  location_easting_osgr  \
# 0      2020010219808           2020          010219808               521389.0
# 1      2020010220496           2020          010220496               529337.0
# 2      2020010228005           2020          010228005               526432.0
# 3      2020010228006           2020          010228006               538676.0
# 4      2020010228011           2020          010228011               529324.0
# ...              ...            ...                ...                    ...
# 91194  2020991027064           2020          991027064               343034.0
# 91195  2020991029573           2020          991029573               257963.0
# 91196  2020991030297           2020          991030297               383664.0
# 91197  2020991030900           2020          991030900               277161.0
# 91198  2020991032575           2020          991032575               240402.0
#
# ...

# %%
# Replacing all NaN values with 'Unknown'
# accident_df.fillna('Unknown', inplace=True)
accident_df_drop=accident_df.dropna()

# %%
accident_df_drop.isnull().sum()
# Out:
# accident_index                                 0
# accident_year                                  0
# accident_reference                             0
# location_easting_osgr                          0
# location_northing_osgr                         0
# longitude                                      0
# latitude                                       0
# police_force                                   0
# accident_severity                              0
# number_of_vehicles                             0
# number_of_casualties                           0
# date                                           0
# day_of_week                                    0
# time                                           0
# local_authority_district                       0
# local_authority_ons_district                   0
# local_authority_highway                        0
# first_road_class                               0
# first_road_number                              0
# ...

# %%
a_severity = pd.get_dummies(accident_df.accident_severity, prefix="severity")

# %%
a_severity

# %%
a_severity = pd.get_dummies(accident_df.accident_severity, prefix="severity", dtype=int)

# %%
a_severity

# %%
s_severity = pd.get_dummies(accident_df.speed_limit, prefix="speed", dtype=int)

# %%
s_severity

# %%
w_severity = pd.get_dummies(accident_df.weather_conditions, prefix="weather", dtype=int)

# %%
w_severity

# %%
df_onehot_encode = pd.concat([a_severity, s_severity, w_severity], axis=1)
df_onehot_encode

# %%
apriori(df_onehot_encode, min_support=0.2, use_colnames=True)

# %%
# Workshop 5
accident_df.isna().any()

# %%
from sklearn.cluster import KMeans
import numpy as np
X = np.array(list(zip(accident_df_drop['latitude'],accident_df_drop['longitude'])))
print(X)
#X = X.reshape(-1,1)
#print(X)
kmeans = KMeans(n_clusters=25, random_state=42).fit(X)

# %%
accident_df

# %%
accident_df_drop

# %%
kmeans.labels_
kmeans.predict(X)
kmeans.cluster_centers_

# %%
import matplotlib.pyplot as plt

fig=plt.figure(figsize=(9,7))
plt.scatter(accident_df_drop['longitude'],accident_df_drop['latitude'],s=1)
plt.scatter(kmeans.cluster_centers_[:,1],kmeans.cluster_centers_[:,0],marker='*',c='red')
